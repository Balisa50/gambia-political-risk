# %% [markdown]
# # 02, Preprocessing
#
# Lowercase, strip HTML/URLs/emails/non-text characters, tokenise, remove stopwords, lemmatise (WordNet), drop short tokens, drop empty rows, de-duplicate.
#
# **Why apostrophes are kept**: English contractions ('dont', 'isnt') lose meaning if apostrophes are dropped before lemmatisation.

# %%
from src.preprocessor import run
df = run()
print(f'cleaned dataset: {len(df)} rows')

# %%
print(df['source'].value_counts())
print()
print('date range:', df['date'].min(), 'to', df['date'].max())
