# %% [markdown]
# # 08, Evaluation summary
#
# Tables that compare every modelling decision: VADER vs distilBERT, LDA k sweep, PRI event matches, correlation analysis. Plain-English interpretation.

# %%
# This notebook reads the artefacts from 05/06/07 and renders the
# summary tables that go in the README.
